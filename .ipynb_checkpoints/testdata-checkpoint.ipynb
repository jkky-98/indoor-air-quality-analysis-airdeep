# %%
import pandas as pd

class read_csv:
    def __init__(self, path):
        self.path = path
        
    def time_str_adjust(self,str_):
        return str_.replace(' KST', '')
    
    def transform(self):
        df_co2 = pd.read_excel(self.path, sheet_name = 'S1.data.#5004', header=1, index_col=0).reset_index(drop=False) # CO2
        df_co2.rename(columns={'Unnamed: 1' : 'co2'}, inplace=True)
        df_pm25 = pd.read_excel(self.path, sheet_name = 'S1.data.#5009', header=1, index_col=0).reset_index(drop=False) # pm2.5 초미세먼지
        df_pm25.rename(columns={'Unnamed: 1' : 'pm25'}, inplace=True)
        df_pm10 = pd.read_excel(self.path, sheet_name = 'S1.data.#500A', header=1, index_col=0).reset_index(drop=False) # pm10 미세먼지
        df_pm10.rename(columns={'Unnamed: 1' : 'pm10'}, inplace=True)
        df_tem = pd.read_excel(self.path, sheet_name = 'S1.data.#500C', header=1, index_col=0).reset_index(drop=False) # humid
        df_tem.rename(columns={'Unnamed: 1' : 'tem'}, inplace=True)
        df_hum = pd.read_excel(self.path, sheet_name = 'S1.data.#500E', header=1, index_col=0).reset_index(drop=False) # temperature
        df_hum.rename(columns={'Unnamed: 1' : 'hum'}, inplace=True)
        df_voc = pd.read_excel(self.path, sheet_name = 'S1.data.#500F', header=1, index_col=0).reset_index(drop=False) # VOC
        df_voc.rename(columns={'Unnamed: 1' : 'voc'}, inplace=True)
        
        df_lst =[df_pm25, df_pm10,
                     df_tem, df_hum, df_voc]
        
        df = df_co2
        for i in df_lst:
            df = pd.merge(df, i, how='left', on='index')
        
        df.rename(columns={'index' : 'datetime'}, inplace=True)
        df['datetime'] = df['datetime'].transform(self.time_str_adjust, axis=0)
        df['datetime'] = pd.to_datetime(df.datetime)
        df.reset_index(drop=True, inplace=True)
        return df

# %%
test = read_csv('/Users/jkky/Documents/air_deep/testdata/BB_care1.csv')
df =test.transform()
df
# Out:
#                datetime  co2  pm25  pm10  tem  hum
# 0   2023-03-20 00:01:00  900    53    68   27   17
# 1   2023-03-20 00:16:00  902    55    71   27   17
# 2   2023-03-20 00:31:00  903    61    74   27   17
# 3   2023-03-20 00:46:00  888    54    77   27   17
# 4   2023-03-20 01:01:00  890    60    67   27   17
# ..                  ...  ...   ...   ...  ...  ...
# 657 2023-03-26 22:58:00  815     5     7   16   19
# 658 2023-03-26 23:13:00  805     5     6   16   19
# 659 2023-03-26 23:28:00  808     6     6   17   19
# 660 2023-03-26 23:43:00  810     6    10   17   19
# 661 2023-03-26 23:58:00  811     7    12   17   19
#
# [662 rows x 6 columns]

# %%
df_co2 = pd.read_excel('/Users/jkky/Documents/air_deep/testdata/BB_care1.csv', sheet_name = 'S1.data.#5004', header=1, index_col=0).reset_index(drop=False) # CO2
df_co2['index'][0].replace(' KST', '')
# Out:
# '2023-03-20 00:01'

# %%
import matplotlib.pyplot as plt

f, axes = plt.subplots(3, 2)
f.set_size_inches((20, 15))
plt.subplots_adjust(wspace = 0.3, hspace = 0.3)

# [0, 1] 위치 막대 그래프
axes[0, 0].plot(df.datetime, df.co2, color = 'b', alpha = 1 )
axes[0, 0].set_title('co2', size=20)
axes[0, 1].plot(df.datetime, df.pm25, color = 'r', alpha = 1 )
axes[0, 1].set_title('pm25', size=20)
axes[1, 0].plot(df.datetime, df.pm10, color = 'g', alpha = 1 )
axes[1, 0].set_title('pm10', size=20)
axes[1, 1].plot(df.datetime, df.tem, color = 'black', alpha = 1)
axes[1, 1].set_title('tem', size=20)
axes[2, 0].plot(df.datetime, df.hum, color = 'purple', alpha = 1 )
axes[2, 0].set_title('hum', size=20)
# Out:
# Text(0.5, 1.0, 'hum')

# %%
df.corr()
# Out:
#            co2      pm25      pm10       tem       hum
# co2   1.000000  0.256735  0.271597  0.174680  0.324887
# pm25  0.256735  1.000000  0.991524  0.078259 -0.477907
# pm10  0.271597  0.991524  1.000000  0.077780 -0.465322
# tem   0.174680  0.078259  0.077780  1.000000  0.176922
# hum   0.324887 -0.477907 -0.465322  0.176922  1.000000
